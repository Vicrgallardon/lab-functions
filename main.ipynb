# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a>b:
        return a
    else:
        return b

# %%
greater(2,3)
# Out:
# 3

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.061s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    largest = 0
    for x in arr:
        if x > largest:
            largest = x
    return largest

# %%
#clase uso del menos infinito 

def greatest(arr):
    largest = float("-inf")
    for x in arr:
        if x > largest:
            largest = x
    return largest

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.091s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
#def sum_all(arr):
    #suma=0
    #for x in range(0,len(arr[x])):
        #suma=suma+sum(arr[x])
   # return suma

# %%
def sum_all(arr):
    suma=0
    for x in arr:
        suma=suma+x  #se puede simplificar suma+=x
    return suma

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.102s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    multi=1
    for x in arr:
        multi=multi*x
    return multi

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.088s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
#def oper_all(arr, oper):
    #multisuma=suma+multi
    #suma=0
    #for x in arr,oper:
    #    suma=suma+x
    #return suma

    #multi=1
    #for x in arr,oper:
   #     multi=multi*x
   # return multi
   # return(multisuma)

# %%
def oper_all(arr, oper):
    if oper == "+": 
        operacion=0
        for x in arr:
            operacion+=x
        return(operacion)
    elif oper == "*":
        operacion=1
        for x in arr:
            operacion*=x
        return operacion

# %%
####Clase 
def oper_all(arr, oper):
    if oper == "+": 
        return sum_all(arr) 
    elif oper == "*":
        return mult_all(arr)
    else raise Expetion("Dame un carcter que entienda")
# Out:
#   File "<ipython-input-28-55b7cdfc1c92>", line 7
#     else raise Expetion("Dame un carcter que entienda")
#          ^
# SyntaxError: invalid syntax

# %%
oper_all([2,3,4], "+")
# Out:
# 9

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.095s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.064s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    unico=[]
    for n in arr:
        if x not in unico:
            unico.append(x)
        return unico

# %%
# This will test your function 
test_unique(unique)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "<ipython-input-29-2f395e90bddd>", line 4, in unique
#     if x not in unico:
# NameError: name 'x' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.086s
#
# FAILED (errors=100)

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    moda=
    for x in arr
    return

# %%
def mode_counter(arr):
    #fill a dictionary with counts

# %%
# This will test your function 
test_mode(mode_counter)

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(arr):
    listadesviacion=[]
    for x in arr:
    desviacion=((x-(sum(listadesviacion)/len(listadesviacion))/(len(listadesviacion)-1))
# Out:
#   File "<ipython-input-138-736b63f8bfb4>", line 5
#     desviacion=((x-(sum(listadesviacion)/len(listadesviacion))/(len(listadesviacion)-1))
#     ^
# IndentationError: expected an indented block

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-6ff7c733d60c> in <module>
# ----> 1 sum(arr)
#
# NameError: name 'arr' is not defined

# %%
from statistics import stdev
print(stdev)
# Out:
# <function stdev at 0x10d931670>

# %%
# This will test your function 
test_stdev(st_dev)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    if  ("ABCDEFGHIJKLMNOPQRSTUVWXYZ") is in string()
    return(string)
# Out:
#   File "<ipython-input-215-649d2029e721>", line 2
#     if  ("ABCDEFGHIJKLMNOPQRSTUVWXYZ") is in string()
#                                           ^
# SyntaxError: invalid syntax

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    if string

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
        if len(string)>=8:
            string.islower == False
            string.isupper == False
            range(0,11) == string
            ("#, @, !, $, %, &, (, ), ^, *, [, ], {, }") == string
            
            return(True)

# %%
#creando funciones 

def is_long(string):
    return len(string) >=8

# %%
def has_number(string):
    for i in range(10):
        if str(i) in string:
            return True
        
    return False

# %%
check_pass("string")

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# FFFFFFFFFFFFFFFFF.FF...F.FF.FFFFFFFF..FFFFFF.FFF..FFFFFFF..F.FFFFFFFFFFFFFFF..FFFFFFFFF..FF.FF.FF..F
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/victoriaruiz-gallardonlopez-monis/Desktop/vrg/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: None != False : Should be False
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.079s
#
# FAILED (failures=78)

# %%
# Out:
# True
